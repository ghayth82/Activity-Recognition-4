# %%
from numpy import linalg as LA
import os
import pandas as pd
import numpy as np
from scipy.signal import find_peaks_cwt
import pickle
from pathlib import Path
from scipy.stats import kurtosis, skew
from scipy.stats import iqr
from pyentrp import entropy as ent
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import precision_score, recall_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import normalize
import sys
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Compute features for accelerometer only

# %%
#Helper Functions

def Signal_magnitude_area(x,y,z):
    
    sum = 0    
    for i in range(len(x)):
        sum += (abs(x[i]) + abs(y[i]) + abs(z[i]))
        
    return float(sum)/len(x)


def Power(x):
    
    power = (LA.norm(x)**2)/ len(x)
    return power
    
def number_of_peaks(window):
    indexes = find_peaks_cwt(window, np.arange(1, len(window)))

    return len(indexes)

#this function assumes that records are evenly spaced
def trim_first_last_n_seconds(df, n, freq):
    if df.shape[0] < 6001:
        return None
    
    remove_indexes = list(range(0, int(n*1000/freq)))
    df = df.drop(remove_indexes)

    remove_indexes = list(range(df.shape[0] - int(n*1000/freq), df.shape[0]-1))
    df = df.drop(remove_indexes)
    
    return df
    
def load_files(indir,pickles_indir):
    trim_num_seconds = 10
    acc_freq = 4
    window_num_seconds = 4 #seconds
    steps_per_sec = int(1000/acc_freq)
    window_size = 10#int(window_num_seconds*steps_per_sec)
    window_step = 2 #seconds
    window_jump_steps = 5#int(window_step*steps_per_sec)
    dfs_list = []
    features = []
    labels = []
    bypass = True
    pickle_file = Path(pickles_indir+"/img_accelerometer_features.pickle")
    
    if pickle_file.exists():
        print("Found pickle files for accelerometer")
        features = pickle.load(open(pickles_indir+"/img_accelerometer_features.pickle", "rb"))
        labels = pickle.load(open(pickles_indir+"/img_accelerometer_labels.pickle", "rb"))
        dfs_list = pickle.load(open(pickles_indir+"/img_accelerometer_dfs_list.pickle", "rb"))

    else:

        for root, dirs, files in os.walk(indir):
            path = root.split(os.sep)
            for f in files:
                print("/".join(path) + "/" + f)
                full_path = "/".join(path) + "/" + f
                if "gyroscope" in full_path:
                    print("Skip ", full_path)
                    continue
                df = pd.read_csv(full_path, header=None)

                print("Before trimming: ", df.shape)

                df = trim_first_last_n_seconds(df, trim_num_seconds, acc_freq)
                if df is None:
                    print("Continuing")
                    continue

                print("After trimming: ", df.shape)

                #Sample the data according to the size of the window with 50% overlap
                for index in range(0, df.shape[0]-window_size, window_jump_steps):
                    indexes = list(range(index, index + int(window_size)))

                    window = df.iloc[indexes,:]

                    X_list = window[1].tolist()
                    Y_list = window[2].tolist()
                    Z_list = window[3].tolist()


                    #Generate the features for this window


           # ****************** Time-Domain Features ************************* #

                    #Mean of the signals
                    mean_x = np.mean(X_list)
                    mean_y = np.mean(Y_list)
                    mean_z = np.mean(Z_list)

                    #Variance of the signals
                    var_x = np.var(X_list)
                    var_y = np.var(Y_list)
                    var_z = np.var(Z_list)

                    #Number of peaks in the signals
                    #num_peaks_x = number_of_peaks(X_list)
                    #num_peaks_y = number_of_peaks(Y_list)
                    #num_peaks_z = number_of_peaks(Z_list)            

                    #Median of the signals
                    median_x = np.ma.median(X_list)
                    median_y = np.ma.median(Y_list)
                    median_z = np.ma.median(Z_list)

                    #Standard Deviation of the signals
                    std_x = np.std(X_list)
                    std_y = np.std(Y_list)
                    std_z = np.std(Z_list)

                    #Compute Signal Magnitude Area
                    signal_mag_area = Signal_magnitude_area(X_list, Y_list, Z_list)

                    #Maximum and Minimum values and their indexes
                    max_x = max(X_list)
                    max_index_x = X_list.index(max_x)               
                    min_x = min(X_list)
                    min_index_x = X_list.index(min_x)

                    max_y = max(Y_list)
                    max_index_y = Y_list.index(max_y)              
                    min_y = min(Y_list)
                    min_index_y = Y_list.index(min_y)               

                    max_z = max(Z_list)
                    max_index_z = Z_list.index(max_z)             
                    min_z = min(Z_list)
                    min_index_z = Z_list.index(min_z)


                    #Power of X,Y and Z signals             
                    power_x = Power(X_list)
                    power_y = Power(Y_list)
                    power_z = Power(Z_list)


                    #Skewness and Kurtosis
                    skew_x = skew(X_list)
                    skew_y = skew(Y_list)
                    skew_z = skew(Z_list)

                    kurtosis_x = kurtosis(X_list)                
                    kurtosis_y = kurtosis(Y_list)
                    kurtosis_z = kurtosis(Z_list)


                    #Entropy of the signals (Can experiment with different types of Entropy)
                    entropy_x = ent.shannon_entropy(X_list)
                    entropy_y = ent.shannon_entropy(Y_list)
                    entropy_z = ent.shannon_entropy(Z_list)


                    #Interquartile range of the signals
                    iqr_x = iqr(X_list)
                    iqr_y = iqr(Y_list)
                    iqr_z = iqr(Z_list)


        # ****************** Frequency-Domain Features ************************* #

                    #Normalized FFT coefficients
                    fft_x = LA.norm(np.fft.rfft(X_list))              
                    fft_y = LA.norm(np.fft.rfft(Y_list))   
                    fft_z = LA.norm(np.fft.rfft(Z_list))  


                    #Store the features
                    window_feature = []
                    window_feature.append(mean_x)
                    window_feature.append(mean_y)
                    window_feature.append(mean_z)

                    window_feature.append(var_x)
                    window_feature.append(var_y)
                    window_feature.append(var_z)

                    window_feature.append(median_x)
                    window_feature.append(median_y)
                    window_feature.append(median_z)

                    window_feature.append(std_x)
                    window_feature.append(std_y)
                    window_feature.append(std_z)


                    window_feature.append(signal_mag_area)

                    window_feature.append(max_x)
                    window_feature.append(max_index_x)
                    window_feature.append(min_x)
                    window_feature.append(min_index_x)

                    window_feature.append(max_y)
                    window_feature.append(max_index_y)
                    window_feature.append(min_y)
                    window_feature.append(min_index_y)

                    window_feature.append(max_z)
                    window_feature.append(max_index_z)
                    window_feature.append(min_z)
                    window_feature.append(min_index_z)

                    window_feature.append(power_x)
                    window_feature.append(power_y)
                    window_feature.append(power_z)

                    window_feature.append(skew_x)
                    window_feature.append(kurtosis_x) 

                    window_feature.append(skew_y)
                    window_feature.append(kurtosis_y) 

                    window_feature.append(skew_z)
                    window_feature.append(kurtosis_z) 

                    window_feature.append(entropy_x)
                    window_feature.append(entropy_y)
                    window_feature.append(entropy_z)

                    window_feature.append(iqr_x)
                    window_feature.append(iqr_y)
                    window_feature.append(iqr_z)

                    window_feature.append(fft_x)
                    window_feature.append(fft_y)
                    window_feature.append(fft_z)


                    #window_feature.append(num_peaks_x)
                    #window_feature.append(num_peaks_y)
                    #window_feature.append(num_peaks_z)

                    #scale = preprocessing.minmax_scale(data, feature_range=(-0.5, 0.5))

                    features.append(window_feature)

                    labels.append(df[5].iloc[1])
                dfs_list.append(df)
        dfs = pd.concat(dfs_list)
        if not os.path.exists(pickles_indir):
            os.mkdir(pickles_indir)
        pickle.dump(features, open(pickles_indir+"/img_accelerometer_features.pickle", "wb"), protocol=2)
        pickle.dump(labels, open(pickles_indir+"/img_accelerometer_labels.pickle", "wb"), protocol=2)
        pickle.dump(dfs_list, open(pickles_indir+"/img_accelerometer_dfs_list.pickle", "wb"), protocol=2)

    features = np.asarray(features)
    labels = np.asarray(labels)
    return features, labels

# %% [markdown]
# ### Loading test and train features from appropriate directories

# %%
print('loading train')
features_train, labels_train = load_files(indir='data_3_8_2018',pickles_indir='img_pickles_train')
print('loading test')
features_test, labels_test = load_files(indir='test3',pickles_indir='img_pickles_test')
# Out:
# loading train
# data_3_8_2018/0_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (40642, 6))
# ('After trimming: ', (35643, 6))
# data_3_8_2018/0_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/0_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/10_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (137412, 6))
# ('After trimming: ', (132413, 6))
# data_3_8_2018/10_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/10_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/11_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (100066, 6))
# ('After trimming: ', (95067, 6))
# data_3_8_2018/11_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/11_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/12_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (64964, 6))
# ('After trimming: ', (59965, 6))
# data_3_8_2018/12_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/12_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/13_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (50274, 6))
# ('After trimming: ', (45275, 6))
# data_3_8_2018/13_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/13_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/14_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (59060, 6))
# ('After trimming: ', (54061, 6))
# data_3_8_2018/14_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/14_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/15_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (55316, 6))
# ('After trimming: ', (50317, 6))
# data_3_8_2018/15_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/15_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/16_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (48531, 6))
# ('After trimming: ', (43532, 6))
# data_3_8_2018/16_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/16_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/17_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (63094, 6))
# ('After trimming: ', (58095, 6))
# data_3_8_2018/17_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/17_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/18_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (63971, 6))
# ('After trimming: ', (58972, 6))
# data_3_8_2018/18_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/18_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/19_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (64212, 6))
# ('After trimming: ', (59213, 6))
# data_3_8_2018/19_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/19_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/1_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (33446, 6))
# ('After trimming: ', (28447, 6))
# data_3_8_2018/1_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/1_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/20_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (64175, 6))
# ('After trimming: ', (59176, 6))
# data_3_8_2018/20_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/20_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/21_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (52095, 6))
# ('After trimming: ', (47096, 6))
# data_3_8_2018/21_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/21_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/22_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (64675, 6))
# ('After trimming: ', (59676, 6))
# data_3_8_2018/22_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/22_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/23_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (66938, 6))
# ('After trimming: ', (61939, 6))
# data_3_8_2018/23_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/23_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/24_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (60980, 6))
# ('After trimming: ', (55981, 6))
# data_3_8_2018/24_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/24_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/25_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (62506, 6))
# ('After trimming: ', (57507, 6))
# data_3_8_2018/25_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/25_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/26_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (65108, 6))
# ('After trimming: ', (60109, 6))
# data_3_8_2018/26_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/26_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/27_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (62588, 6))
# ('After trimming: ', (57589, 6))
# data_3_8_2018/27_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/27_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/28_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (82181, 6))
# ('After trimming: ', (77182, 6))
# data_3_8_2018/28_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/28_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/29_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (83784, 6))
# ('After trimming: ', (78785, 6))
# data_3_8_2018/29_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/29_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/2_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (53344, 6))
# ('After trimming: ', (48345, 6))
# data_3_8_2018/2_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/2_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/30_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (85978, 6))
# ('After trimming: ', (80979, 6))
# data_3_8_2018/30_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/30_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/31_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (101168, 6))
# ('After trimming: ', (96169, 6))
# data_3_8_2018/31_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/31_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/32_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (53812, 6))
# ('After trimming: ', (48813, 6))
# data_3_8_2018/32_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/32_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/33_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (65720, 6))
# ('After trimming: ', (60721, 6))
# data_3_8_2018/33_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/33_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/34_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (71074, 6))
# ('After trimming: ', (66075, 6))
# data_3_8_2018/34_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/34_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/35_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (30053, 6))
# ('After trimming: ', (25054, 6))
# data_3_8_2018/35_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/35_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/36_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (26070, 6))
# ('After trimming: ', (21071, 6))
# data_3_8_2018/36_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/36_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/37_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (66885, 6))
# ('After trimming: ', (61886, 6))
# data_3_8_2018/37_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/37_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/38_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (68901, 6))
# ('After trimming: ', (63902, 6))
# data_3_8_2018/38_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/38_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/39_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (69512, 6))
# ('After trimming: ', (64513, 6))
# data_3_8_2018/39_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/39_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/3_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (31018, 6))
# ('After trimming: ', (26019, 6))
# data_3_8_2018/3_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/3_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/40_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (67293, 6))
# ('After trimming: ', (62294, 6))
# data_3_8_2018/40_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/40_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/41_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (67641, 6))
# ('After trimming: ', (62642, 6))
# data_3_8_2018/41_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/41_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/42_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (40200, 6))
# ('After trimming: ', (35201, 6))
# data_3_8_2018/42_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/42_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/43_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (118805, 6))
# ('After trimming: ', (113806, 6))
# data_3_8_2018/43_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/43_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/44_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (65634, 6))
# ('After trimming: ', (60635, 6))
# data_3_8_2018/44_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/44_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/45_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (98968, 6))
# ('After trimming: ', (93969, 6))
# data_3_8_2018/45_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/45_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/46_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (96365, 6))
# ('After trimming: ', (91366, 6))
# data_3_8_2018/46_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/46_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/47_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (2323, 6))
# Continuing
# data_3_8_2018/47_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/47_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/48_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (43060, 6))
# ('After trimming: ', (38061, 6))
# data_3_8_2018/48_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/48_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/49_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (83999, 6))
# ('After trimming: ', (79000, 6))
# data_3_8_2018/49_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/49_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/4_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (51852, 6))
# ('After trimming: ', (46853, 6))
# data_3_8_2018/4_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/4_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/50_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (65899, 6))
# ('After trimming: ', (60900, 6))
# data_3_8_2018/50_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/50_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/51_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (89512, 6))
# ('After trimming: ', (84513, 6))
# data_3_8_2018/51_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/51_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/52_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (59739, 6))
# ('After trimming: ', (54740, 6))
# data_3_8_2018/52_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/52_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/53_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (57828, 6))
# ('After trimming: ', (52829, 6))
# data_3_8_2018/53_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/53_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/54_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (35267, 6))
# ('After trimming: ', (30268, 6))
# data_3_8_2018/54_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/54_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/55_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (52974, 6))
# ('After trimming: ', (47975, 6))
# data_3_8_2018/55_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/55_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/56_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (147020, 6))
# ('After trimming: ', (142021, 6))
# data_3_8_2018/56_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/56_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/57_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (99784, 6))
# ('After trimming: ', (94785, 6))
# data_3_8_2018/57_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/57_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/58_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (9650, 6))
# ('After trimming: ', (4651, 6))
# data_3_8_2018/58_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/58_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/59_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (73355, 6))
# ('After trimming: ', (68356, 6))
# data_3_8_2018/59_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/59_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/5_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (49109, 6))
# ('After trimming: ', (44110, 6))
# data_3_8_2018/5_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/5_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/60_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (177495, 6))
# ('After trimming: ', (172496, 6))
# data_3_8_2018/60_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/60_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/61_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (165062, 6))
# ('After trimming: ', (160063, 6))
# data_3_8_2018/61_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/61_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/62_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (355411, 6))
# ('After trimming: ', (350412, 6))
# data_3_8_2018/62_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/62_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/63_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (149453, 6))
# ('After trimming: ', (144454, 6))
# data_3_8_2018/63_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/63_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/64_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (138601, 6))
# ('After trimming: ', (133602, 6))
# data_3_8_2018/64_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/64_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/65_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (106594, 6))
# ('After trimming: ', (101595, 6))
# data_3_8_2018/65_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/65_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/66_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (168816, 6))
# ('After trimming: ', (163817, 6))
# data_3_8_2018/66_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/66_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/67_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (225124, 6))
# ('After trimming: ', (220125, 6))
# data_3_8_2018/67_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/67_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/68_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (317906, 6))
# ('After trimming: ', (312907, 6))
# data_3_8_2018/68_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/68_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/69_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (160230, 6))
# ('After trimming: ', (155231, 6))
# data_3_8_2018/69_4_android.sensor.gyroscope.data.csv
# ('Skip ', 'data_3_8_2018/69_4_android.sensor.gyroscope.data.csv')
# data_3_8_2018/6_1_android.sensor.accelerometer.data.csv
# ('Before trimming: ', (28988, 6))
# ('After trimming: ', (23989, 6))

# %%
## Using LDA to reduce the fimensions into 3

# %%
labels_copy_train = labels_train
labels_copy_test = labels_test
features_copy_train = features_labels_train
features_copy_test = features_test

# %%
print(features_train.shape)
print(labels_train.shape)
print(features_test.shape)
print(labels_test.shape)
# Out:
# (1183508, 1)
# (1183508,)
# (166181, 1)
# (166181,)

# %%
labels_copy_train = ['not_walking' if not x=='walking' else 'walking' for x in labels_copy_train]
labels_copy_test = ['not_walking' if not x=='walking' else 'walking' for x in labels_copy_test]
print(np.unique(labels_copy_test))
print(np.unique(labels_copy_train))
# Out:
# ['not_walking' 'walking']
# ['not_walking' 'walking']

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=3)

# %%
features_train = lda.fit(features_train, np.asarray(labels_copy_train)).transform(features_train)
features_test = lda.transform(features_test)

# %%
print(features_train.shape)
print(labels_train.shape)
print(features_test.shape)
print(labels_test.shape)
# Out:
# (1183508, 1)
# (1183508,)
# (166181, 1)
# (166181,)

# %% [markdown]
# ## Put the train and test features into dataframe

# %%
features_df_train = pd.DataFrame(features_train,columns=['a','b','c'])
labels_df_train = pd.DataFrame(labels_copy_train,columns=['l'])
features_df_test = pd.DataFrame(features_test,columns=['a','b','c'])
labels_df_test = pd.DataFrame(labels_copy_test,columns=['l'])

# %%
print(np.unique(labels_copy_test))
# Out:
# ['not_walking' 'walking']

# %%
features_df_train['l'] = labels_df_train['l']
features_df_test['l'] = labels_df_test['l']

# %%
activities = ['walking','sitting','standing','laying_down']

# %%
activities =['walking','not_walking']

# %% [markdown]
# ## Findind the minimum and maximum using 1 stddev away from mean

# %%
max_=[]
min_=[]
for axis in ['a','b','c']:
    print('axis',axis)
    mean =np.mean(features_df_train[axis])
    std =np.std(features_df_train[axis]) 
    print(mean,std)
    print(np.min(features_df_train[axis]),np.max(features_df_train[axis]))
    max_.append(mean+2*std)
    min_.append(mean-2*std)
    #max_.append()
# Out:
# ('axis', 'a')
# (5.7716215347198105e-12, 1.91922926997777)
# (-31.62189545806002, 10.543340943243994)
# ('axis', 'b')
# (-7.77187738633384e-13, 1.2881504023883437)
# (-32.04581690335029, 14.01614505360675)
# ('axis', 'c')
# (1.6091897214039542e-13, 1.1460491956299006)
# (-38.524362911029634, 8.237474300465975)

# %%
max_
# Out:
# [3.838458539961312, 2.57630080477591, 2.292098391259962]

# %%
min_
# Out:
# [-3.838458539949768, -2.5763008047774645, -2.2920983912596404]

# %% [markdown]
# ## Functions to scale features from feature values to colrs

# %%
def get_color(i,num):
    scale_ = 255 /(max_[i]-min_[i])
    num = max(min_[i],num)
    num = min(num,max_[i])
    return (num - min_[i])*scale_
def get_rgb(feature):
    #print(feature)
    feature = list(feature)
    #print(feature)
    col = []
    for i in range(0,3):
        col.append(int(get_color(i,feature[i])))
    #col[1] = 0
    return col

# %%
def spiral(lst,n):
    dx,dy = 1,0            # Starting increments
    x,y = 0,0              # Starting location
    myarray = [[None]* n for j in range(n)]
    for i in range(n**2):
        myarray[x][y] = lst[i]
        nx,ny = x+dx, y+dy
        if 0<=nx<n and 0<=ny<n and myarray[nx][ny] == None:
            x,y = nx,ny
        else:
            dx,dy = -dy,dx
            x,y = x+dx, y+dy
    return myarray

# %% [markdown]
# ## Features converted to 0 - 255

# %%
array_map_train={}
array_map_test={}
for activity in activities:
    print('train')
    df = features_df_train[features_df_train['l']==activity][['a','b','c']].copy()
    print(df.shape)
    array_map_train[activity] = (df.as_matrix())
    print((array_map_train[activity][2]))
    print('test')
    df = features_df_test[features_df_test['l']==activity][['a','b','c']].copy()
    print(df.shape)
    array_map_test[activity] = (df.as_matrix())
    print((array_map_test[activity][2]))
# Out:
# train
# (317822, 3)
# [ 1.43134746 -0.73815934  1.62548252]
# test
# (18856, 3)
# [ 2.84198523 -0.75064632 -1.39818406]
# train
# (286720, 3)
# [-1.93302792 -0.16730912  0.66142161]
# test
# (46629, 3)
# [ 0.79655389 -1.03309884 -0.95708547]
# train
# (276870, 3)
# [ 2.13052628 -0.95745858 -1.30124221]
# test
# (17313, 3)
# [-1.12413381  1.21064526 -2.36662753]
# train
# (302096, 3)
# [-1.6907363   4.01332736 -1.46883218]
# test
# (83383, 3)
# [-0.06396953 -0.47449681  0.09974866]

# %%
color_map_train = {}
color_map_test = {}
for activity in activities:
    color_map_train[activity] = [get_rgb(x) for x in array_map_train[activity]]
    print(color_map_train[activity][1])
    color_map_test[activity] = [get_rgb(x) for x in array_map_test[activity]]
    print(color_map_test[activity][1])
# Out:
# [187, 79, 205]
# [241, 118, 99]
# [54, 122, 166]
# [126, 85, 74]
# [200, 80, 65]
# [83, 191, 0]
# [64, 255, 37]
# [120, 117, 146]

# %% [markdown]
# ## Coverting to square images

# %%
from collections import defaultdict
color_map_spiral_train = defaultdict(list)
color_map_spiral_test = defaultdict(list)
for activity in activities:
    print(activity)
    siz = len(color_map_train[activity])
    for i in range((siz/625)-1):
        sp = spiral(color_map_train[activity][i*625:(i+1)*625],25)
        color_map_spiral_train[activity].append(sp)
    print(len(color_map_spiral_train[activity]))
    siz = len(color_map_test[activity])
    for i in range((siz/625)-1):
        sp = spiral(color_map_test[activity][i*625:(i+1)*625],25)
        color_map_spiral_test[activity].append(sp)
    print(len(color_map_spiral_test[activity]))
# Out:
# walking
# 507
# 29
# sitting
# 457
# 73
# standing
# 441
# 26
# laying_down
# 482
# 132

# %% [markdown]
# ## Storing the images

# %%
from PIL import Image
import numpy as np

# %%
train_dir = 'img_train'
test_dir = 'img_test'
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

for activity in activities:
    i=0
    print(activity)
    if not os.path.exists(train_dir+'/'+activity):
        os.mkdir(train_dir+'/'+activity)        
    if not os.path.exists(test_dir+'/'+activity):
        os.mkdir(test_dir+'/'+activity)
        
    for spir_arr in color_map_spiral_train[activity]:
        i+=1
        img = Image.fromarray(np.array(spir_arr), 'RGB')
        img.save(train_dir+'/'+activity+'/'+activity+str(i)+'.png')
    
    for spir_arr in color_map_spiral_test[activity]:
        i+=1
        img = Image.fromarray(np.array(spir_arr), 'RGB')
        img.save(test_dir+'/'+activity+'/'+activity+str(i)+'.png')
# Out:
# walking
# sitting
# standing
# laying_down

# %% [markdown]
# # TEST

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

# dimensions of our images.
img_width, img_height = 25, 25

train_data_dir = 'img_train'
validation_data_dir = 'img_test'
test_data_dir = 'img_test'

nb_train_samples = 1711
nb_validation_samples = 178
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

    
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4))
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])


# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save_weights('first_try.h5')
# Out:
# /anaconda/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Found 1887 images belonging to 4 classes.
# Found 260 images belonging to 4 classes.
# Epoch 1/50
# 106/106 [==============================] - 3s 25ms/step - loss: 1.2271 - acc: 0.4178 - val_loss: 0.8104 - val_acc: 0.6477
# Epoch 2/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.9216 - acc: 0.6124 - val_loss: 0.7832 - val_acc: 0.6477
# Epoch 3/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.7771 - acc: 0.7086 - val_loss: 0.7990 - val_acc: 0.6420
# Epoch 4/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.7209 - acc: 0.7446 - val_loss: 0.7118 - val_acc: 0.6477
# Epoch 5/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.6789 - acc: 0.7482 - val_loss: 0.6538 - val_acc: 0.6648
# Epoch 6/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.6732 - acc: 0.7576 - val_loss: 0.7039 - val_acc: 0.6364
# Epoch 7/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.6427 - acc: 0.7723 - val_loss: 0.7238 - val_acc: 0.6648
# Epoch 8/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.6131 - acc: 0.7746 - val_loss: 0.7518 - val_acc: 0.6364
# Epoch 9/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.6073 - acc: 0.7824 - val_loss: 0.7738 - val_acc: 0.6250
# Epoch 10/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.6066 - acc: 0.7830 - val_loss: 0.6764 - val_acc: 0.6705
# Epoch 11/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.6015 - acc: 0.7746 - val_loss: 0.8287 - val_acc: 0.6591
# Epoch 12/50
# 106/106 [==============================] - 2s 21ms/step - loss: 0.5822 - acc: 0.7952 - val_loss: 0.8727 - val_acc: 0.6477
# Epoch 13/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5961 - acc: 0.7759 - val_loss: 0.8234 - val_acc: 0.6648
# Epoch 14/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5762 - acc: 0.7857 - val_loss: 0.8174 - val_acc: 0.6420
# Epoch 15/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5729 - acc: 0.7876 - val_loss: 1.0234 - val_acc: 0.6364
# Epoch 16/50
# 106/106 [==============================] - 2s 20ms/step - loss: 0.5783 - acc: 0.7824 - val_loss: 0.7890 - val_acc: 0.6534
# Epoch 17/50
# 106/106 [==============================] - 2s 17ms/step - loss: 0.5639 - acc: 0.8036 - val_loss: 0.8387 - val_acc: 0.6364
# Epoch 18/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5605 - acc: 0.7954 - val_loss: 0.7113 - val_acc: 0.6932
# Epoch 19/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5557 - acc: 0.7934 - val_loss: 0.7411 - val_acc: 0.6875
# Epoch 20/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5731 - acc: 0.7964 - val_loss: 0.8064 - val_acc: 0.6761
# Epoch 21/50
# 106/106 [==============================] - 2s 21ms/step - loss: 0.5715 - acc: 0.8006 - val_loss: 0.9355 - val_acc: 0.6193
# Epoch 22/50
# 106/106 [==============================] - 2s 20ms/step - loss: 0.5481 - acc: 0.8041 - val_loss: 0.8870 - val_acc: 0.6591
# Epoch 23/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5526 - acc: 0.7930 - val_loss: 1.3152 - val_acc: 0.6420
# Epoch 24/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5636 - acc: 0.8057 - val_loss: 0.9702 - val_acc: 0.6477
# Epoch 25/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5433 - acc: 0.7798 - val_loss: 1.1088 - val_acc: 0.6193
# Epoch 26/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5509 - acc: 0.8037 - val_loss: 1.0929 - val_acc: 0.6420
# Epoch 27/50
# 106/106 [==============================] - 2s 20ms/step - loss: 0.5567 - acc: 0.8041 - val_loss: 1.2185 - val_acc: 0.5909
# Epoch 28/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5280 - acc: 0.8119 - val_loss: 1.3548 - val_acc: 0.6250
# Epoch 29/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5373 - acc: 0.8071 - val_loss: 1.3623 - val_acc: 0.6364
# Epoch 30/50
# 106/106 [==============================] - 2s 17ms/step - loss: 0.5414 - acc: 0.8094 - val_loss: 1.0902 - val_acc: 0.6420
# Epoch 31/50
# 106/106 [==============================] - 2s 20ms/step - loss: 0.5095 - acc: 0.8166 - val_loss: 1.2157 - val_acc: 0.6080
# Epoch 32/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5399 - acc: 0.8082 - val_loss: 0.9934 - val_acc: 0.6420
# Epoch 33/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5438 - acc: 0.8094 - val_loss: 0.8923 - val_acc: 0.6818
# Epoch 34/50
# 106/106 [==============================] - 2s 17ms/step - loss: 0.5129 - acc: 0.8159 - val_loss: 1.1401 - val_acc: 0.6364
# Epoch 35/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5625 - acc: 0.7966 - val_loss: 0.8963 - val_acc: 0.6250
# Epoch 36/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.4974 - acc: 0.8195 - val_loss: 1.0321 - val_acc: 0.6591
# Epoch 37/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5250 - acc: 0.8024 - val_loss: 1.1167 - val_acc: 0.6193
# Epoch 38/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5261 - acc: 0.8089 - val_loss: 1.3676 - val_acc: 0.6420
# Epoch 39/50
# 106/106 [==============================] - 2s 20ms/step - loss: 0.5328 - acc: 0.8058 - val_loss: 1.3717 - val_acc: 0.6136
# Epoch 40/50
# 106/106 [==============================] - 3s 25ms/step - loss: 0.5084 - acc: 0.8078 - val_loss: 1.2972 - val_acc: 0.6250
# Epoch 41/50
# 106/106 [==============================] - 3s 28ms/step - loss: 0.5217 - acc: 0.8094 - val_loss: 1.2407 - val_acc: 0.6761
# Epoch 42/50
# 106/106 [==============================] - 3s 25ms/step - loss: 0.5237 - acc: 0.8118 - val_loss: 1.0658 - val_acc: 0.6193
# Epoch 43/50
# 106/106 [==============================] - 2s 23ms/step - loss: 0.5063 - acc: 0.8160 - val_loss: 0.8803 - val_acc: 0.6364
# Epoch 44/50
# 106/106 [==============================] - 2s 22ms/step - loss: 0.5313 - acc: 0.8153 - val_loss: 1.0674 - val_acc: 0.6136
# Epoch 45/50
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5331 - acc: 0.8053 - val_loss: 0.8868 - val_acc: 0.6477
# Epoch 46/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5062 - acc: 0.8166 - val_loss: 1.2034 - val_acc: 0.6477
# Epoch 47/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5162 - acc: 0.8164 - val_loss: 1.1725 - val_acc: 0.5852
# Epoch 48/50
# 106/106 [==============================] - 2s 19ms/step - loss: 0.5304 - acc: 0.8001 - val_loss: 0.9394 - val_acc: 0.6364
# Epoch 49/50
# 106/106 [==============================] - 2s 23ms/step - loss: 0.4949 - acc: 0.8194 - val_loss: 1.4937 - val_acc: 0.6705
# Epoch 50/50
# 106/106 [==============================] - 2s 22ms/step - loss: 0.5105 - acc: 0.8130 - val_loss: 1.4719 - val_acc: 0.5966

# %%
label_map = (train_generator.class_indices)
label_map
# Out:
# {'laying_down': 0, 'sitting': 1, 'standing': 2, 'walking': 3}

# %%
test_data_dir = 'img_test'

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    #batch_size=batch_size,
    class_mode='categorical')

filenames = test_generator.filenames
nb_samples = len(filenames)

predict = model.predict_generator(test_generator)
# Out:
# Found 260 images belonging to 4 classes.

# %%
train_generator.filenames
# Out:
# ['laying_down/laying_down1.png',
#  'laying_down/laying_down10.png',
#  'laying_down/laying_down100.png',
#  'laying_down/laying_down101.png',
#  'laying_down/laying_down102.png',
#  'laying_down/laying_down103.png',
#  'laying_down/laying_down104.png',
#  'laying_down/laying_down105.png',
#  'laying_down/laying_down106.png',
#  'laying_down/laying_down107.png',
#  'laying_down/laying_down108.png',
#  'laying_down/laying_down109.png',
#  'laying_down/laying_down11.png',
#  'laying_down/laying_down110.png',
#  'laying_down/laying_down111.png',
#  'laying_down/laying_down112.png',
#  'laying_down/laying_down113.png',
#  'laying_down/laying_down114.png',
#  'laying_down/laying_down115.png',
#  'laying_down/laying_down116.png',
#  'laying_down/laying_down117.png',
#  'laying_down/laying_down118.png',
#  'laying_down/laying_down119.png',
#  'laying_down/laying_down12.png',
#  'laying_down/laying_down120.png',
#  'laying_down/laying_down121.png',
#  'laying_down/laying_down122.png',
#  'laying_down/laying_down123.png',
#  'laying_down/laying_down124.png',
#  'laying_down/laying_down125.png',
#  'laying_down/laying_down126.png',
#  'laying_down/laying_down127.png',
#  'laying_down/laying_down128.png',
#  'laying_down/laying_down129.png',
#  'laying_down/laying_down13.png',
#  'laying_down/laying_down130.png',
#  'laying_down/laying_down131.png',
#  'laying_down/laying_down132.png',
#  'laying_down/laying_down133.png',
#  'laying_down/laying_down134.png',
#  'laying_down/laying_down135.png',
#  'laying_down/laying_down136.png',
#  'laying_down/laying_down137.png',
#  'laying_down/laying_down138.png',
#  'laying_down/laying_down139.png',
#  'laying_down/laying_down14.png',
#  'laying_down/laying_down140.png',
#  'laying_down/laying_down141.png',
#  'laying_down/laying_down142.png',
#  'laying_down/laying_down143.png',
#  'laying_down/laying_down144.png',
#  'laying_down/laying_down145.png',
#  'laying_down/laying_down146.png',
#  'laying_down/laying_down147.png',
#  'laying_down/laying_down148.png',
#  'laying_down/laying_down149.png',
#  'laying_down/laying_down15.png',
#  'laying_down/laying_down150.png',
#  'laying_down/laying_down151.png',
#  'laying_down/laying_down152.png',
#  'laying_down/laying_down153.png',
#  'laying_down/laying_down154.png',
#  'laying_down/laying_down155.png',
#  'laying_down/laying_down156.png',
#  'laying_down/laying_down157.png',
#  'laying_down/laying_down158.png',
#  'laying_down/laying_down159.png',
#  'laying_down/laying_down16.png',
#  'laying_down/laying_down160.png',
#  'laying_down/laying_down161.png',
#  'laying_down/laying_down162.png',
#  'laying_down/laying_down163.png',
#  'laying_down/laying_down164.png',
#  'laying_down/laying_down165.png',
#  'laying_down/laying_down166.png',
#  'laying_down/laying_down167.png',
#  'laying_down/laying_down168.png',
#  'laying_down/laying_down169.png',
#  'laying_down/laying_down17.png',
#  'laying_down/laying_down170.png',
#  'laying_down/laying_down171.png',
#  'laying_down/laying_down172.png',
#  'laying_down/laying_down173.png',
#  'laying_down/laying_down174.png',
#  'laying_down/laying_down175.png',
#  'laying_down/laying_down176.png',
#  'laying_down/laying_down177.png',
#  'laying_down/laying_down178.png',
#  'laying_down/laying_down179.png',
#  'laying_down/laying_down18.png',
#  'laying_down/laying_down180.png',
#  'laying_down/laying_down181.png',
#  'laying_down/laying_down182.png',
#  'laying_down/laying_down183.png',
#  'laying_down/laying_down184.png',
#  'laying_down/laying_down185.png',
#  'laying_down/laying_down186.png',
#  'laying_down/laying_down187.png',
#  'laying_down/laying_down188.png',
#  'laying_down/laying_down189.png',
#  'laying_down/laying_down19.png',
#  'laying_down/laying_down190.png',
#  'laying_down/laying_down191.png',
#  'laying_down/laying_down192.png',
#  'laying_down/laying_down193.png',
#  'laying_down/laying_down194.png',
#  'laying_down/laying_down195.png',
#  'laying_down/laying_down196.png',
#  'laying_down/laying_down197.png',
#  'laying_down/laying_down198.png',
#  'laying_down/laying_down199.png',
#  'laying_down/laying_down2.png',
#  'laying_down/laying_down20.png',
#  'laying_down/laying_down200.png',
#  'laying_down/laying_down201.png',
#  'laying_down/laying_down202.png',
#  'laying_down/laying_down203.png',
#  'laying_down/laying_down204.png',
#  'laying_down/laying_down205.png',
#  'laying_down/laying_down206.png',
#  'laying_down/laying_down207.png',
#  'laying_down/laying_down208.png',
#  'laying_down/laying_down209.png',
#  'laying_down/laying_down21.png',
#  'laying_down/laying_down210.png',
#  'laying_down/laying_down211.png',
#  'laying_down/laying_down212.png',
#  'laying_down/laying_down213.png',
#  'laying_down/laying_down214.png',
#  'laying_down/laying_down215.png',
#  'laying_down/laying_down216.png',
#  'laying_down/laying_down217.png',
#  'laying_down/laying_down218.png',
#  'laying_down/laying_down219.png',
#  'laying_down/laying_down22.png',
#  'laying_down/laying_down220.png',
#  'laying_down/laying_down221.png',
#  'laying_down/laying_down222.png',
#  'laying_down/laying_down223.png',
#  'laying_down/laying_down224.png',
#  'laying_down/laying_down225.png',
#  'laying_down/laying_down226.png',
#  'laying_down/laying_down227.png',
#  'laying_down/laying_down228.png',
#  'laying_down/laying_down229.png',
#  'laying_down/laying_down23.png',
#  'laying_down/laying_down230.png',
#  'laying_down/laying_down231.png',
#  'laying_down/laying_down232.png',
#  'laying_down/laying_down233.png',
#  'laying_down/laying_down234.png',
#  'laying_down/laying_down235.png',
#  'laying_down/laying_down236.png',
#  'laying_down/laying_down237.png',
#  'laying_down/laying_down238.png',
#  'laying_down/laying_down239.png',
#  'laying_down/laying_down24.png',
#  'laying_down/laying_down240.png',
#  'laying_down/laying_down241.png',
#  'laying_down/laying_down242.png',
#  'laying_down/laying_down243.png',
#  'laying_down/laying_down244.png',
#  'laying_down/laying_down245.png',
#  'laying_down/laying_down246.png',
#  'laying_down/laying_down247.png',
#  'laying_down/laying_down248.png',
#  'laying_down/laying_down249.png',
#  'laying_down/laying_down25.png',
#  'laying_down/laying_down250.png',
#  'laying_down/laying_down251.png',
#  'laying_down/laying_down252.png',
#  'laying_down/laying_down253.png',
#  'laying_down/laying_down254.png',
#  'laying_down/laying_down255.png',
#  'laying_down/laying_down256.png',
#  'laying_down/laying_down257.png',
#  'laying_down/laying_down258.png',
#  'laying_down/laying_down259.png',
#  'laying_down/laying_down26.png',
#  'laying_down/laying_down260.png',
#  'laying_down/laying_down261.png',
#  'laying_down/laying_down262.png',
#  'laying_down/laying_down263.png',
#  'laying_down/laying_down264.png',
#  'laying_down/laying_down265.png',
#  'laying_down/laying_down266.png',
#  'laying_down/laying_down267.png',
#  'laying_down/laying_down268.png',
#  'laying_down/laying_down269.png',
#  'laying_down/laying_down27.png',
#  'laying_down/laying_down270.png',
#  'laying_down/laying_down271.png',
#  'laying_down/laying_down272.png',
#  'laying_down/laying_down273.png',
#  'laying_down/laying_down274.png',
#  'laying_down/laying_down275.png',
#  'laying_down/laying_down276.png',
#  'laying_down/laying_down277.png',
#  'laying_down/laying_down278.png',
#  'laying_down/laying_down279.png',
#  'laying_down/laying_down28.png',
#  'laying_down/laying_down280.png',
#  'laying_down/laying_down281.png',
#  'laying_down/laying_down282.png',
#  'laying_down/laying_down283.png',
#  'laying_down/laying_down284.png',
#  'laying_down/laying_down285.png',
#  'laying_down/laying_down286.png',
#  'laying_down/laying_down287.png',
#  'laying_down/laying_down288.png',
#  'laying_down/laying_down289.png',
#  'laying_down/laying_down29.png',
#  'laying_down/laying_down290.png',
#  'laying_down/laying_down291.png',
#  'laying_down/laying_down292.png',
#  'laying_down/laying_down293.png',
#  'laying_down/laying_down294.png',
#  'laying_down/laying_down295.png',
#  'laying_down/laying_down296.png',
#  'laying_down/laying_down297.png',
#  'laying_down/laying_down298.png',
#  'laying_down/laying_down299.png',
#  'laying_down/laying_down3.png',
#  'laying_down/laying_down30.png',
#  'laying_down/laying_down300.png',
#  'laying_down/laying_down301.png',
#  'laying_down/laying_down302.png',
#  'laying_down/laying_down303.png',
#  'laying_down/laying_down304.png',
#  'laying_down/laying_down305.png',
#  'laying_down/laying_down306.png',
#  'laying_down/laying_down307.png',
#  'laying_down/laying_down308.png',
#  'laying_down/laying_down309.png',
#  'laying_down/laying_down31.png',
#  'laying_down/laying_down310.png',
#  'laying_down/laying_down311.png',
#  'laying_down/laying_down312.png',
#  'laying_down/laying_down313.png',
#  'laying_down/laying_down314.png',
#  'laying_down/laying_down315.png',
#  'laying_down/laying_down316.png',
#  'laying_down/laying_down317.png',
#  'laying_down/laying_down318.png',
#  'laying_down/laying_down319.png',
#  'laying_down/laying_down32.png',
#  'laying_down/laying_down320.png',
#  'laying_down/laying_down321.png',
#  'laying_down/laying_down322.png',
#  'laying_down/laying_down323.png',
#  'laying_down/laying_down324.png',
#  'laying_down/laying_down325.png',
#  'laying_down/laying_down326.png',
#  'laying_down/laying_down327.png',
#  'laying_down/laying_down328.png',
#  'laying_down/laying_down329.png',
#  'laying_down/laying_down33.png',
#  'laying_down/laying_down330.png',
#  'laying_down/laying_down331.png',
#  'laying_down/laying_down332.png',
#  'laying_down/laying_down333.png',
#  'laying_down/laying_down334.png',
#  'laying_down/laying_down335.png',
#  'laying_down/laying_down336.png',
#  'laying_down/laying_down337.png',
#  'laying_down/laying_down338.png',
#  'laying_down/laying_down339.png',
#  'laying_down/laying_down34.png',
#  'laying_down/laying_down340.png',
#  'laying_down/laying_down341.png',
#  'laying_down/laying_down342.png',
#  'laying_down/laying_down343.png',
#  'laying_down/laying_down344.png',
#  'laying_down/laying_down345.png',
#  'laying_down/laying_down346.png',
#  'laying_down/laying_down347.png',
#  'laying_down/laying_down348.png',
#  'laying_down/laying_down349.png',
#  'laying_down/laying_down35.png',
#  'laying_down/laying_down350.png',
#  'laying_down/laying_down351.png',
#  'laying_down/laying_down352.png',
#  'laying_down/laying_down353.png',
#  'laying_down/laying_down354.png',
#  'laying_down/laying_down355.png',
#  'laying_down/laying_down356.png',
#  'laying_down/laying_down357.png',
#  'laying_down/laying_down358.png',
#  'laying_down/laying_down359.png',
#  'laying_down/laying_down36.png',
#  'laying_down/laying_down360.png',
#  'laying_down/laying_down361.png',
#  'laying_down/laying_down362.png',
#  'laying_down/laying_down363.png',
#  'laying_down/laying_down364.png',
#  'laying_down/laying_down365.png',
#  'laying_down/laying_down366.png',
#  'laying_down/laying_down367.png',
#  'laying_down/laying_down368.png',
#  'laying_down/laying_down369.png',
#  'laying_down/laying_down37.png',
#  'laying_down/laying_down370.png',
#  'laying_down/laying_down371.png',
#  'laying_down/laying_down372.png',
#  'laying_down/laying_down373.png',
#  'laying_down/laying_down374.png',
#  'laying_down/laying_down375.png',
#  'laying_down/laying_down376.png',
#  'laying_down/laying_down377.png',
#  'laying_down/laying_down378.png',
#  'laying_down/laying_down379.png',
#  'laying_down/laying_down38.png',
#  'laying_down/laying_down380.png',
#  'laying_down/laying_down381.png',
#  'laying_down/laying_down382.png',
#  'laying_down/laying_down383.png',
#  'laying_down/laying_down384.png',
#  'laying_down/laying_down385.png',
#  'laying_down/laying_down386.png',
#  'laying_down/laying_down387.png',
#  'laying_down/laying_down388.png',
#  'laying_down/laying_down389.png',
#  'laying_down/laying_down39.png',
#  'laying_down/laying_down390.png',
#  'laying_down/laying_down391.png',
#  'laying_down/laying_down392.png',
#  'laying_down/laying_down393.png',
#  'laying_down/laying_down394.png',
#  'laying_down/laying_down395.png',
#  'laying_down/laying_down396.png',
#  'laying_down/laying_down397.png',
#  'laying_down/laying_down398.png',
#  'laying_down/laying_down399.png',
#  'laying_down/laying_down4.png',
#  'laying_down/laying_down40.png',
#  'laying_down/laying_down400.png',
#  'laying_down/laying_down401.png',
#  'laying_down/laying_down402.png',
#  'laying_down/laying_down403.png',
#  'laying_down/laying_down404.png',
#  'laying_down/laying_down405.png',
#  'laying_down/laying_down406.png',
#  'laying_down/laying_down407.png',
#  'laying_down/laying_down408.png',
#  'laying_down/laying_down409.png',
#  'laying_down/laying_down41.png',
#  'laying_down/laying_down410.png',
#  'laying_down/laying_down411.png',
#  'laying_down/laying_down412.png',
#  'laying_down/laying_down413.png',
#  'laying_down/laying_down414.png',
#  'laying_down/laying_down415.png',
#  'laying_down/laying_down416.png',
#  'laying_down/laying_down417.png',
#  'laying_down/laying_down418.png',
#  'laying_down/laying_down419.png',
#  'laying_down/laying_down42.png',
#  'laying_down/laying_down420.png',
#  'laying_down/laying_down421.png',
#  'laying_down/laying_down422.png',
#  'laying_down/laying_down423.png',
#  'laying_down/laying_down424.png',
#  'laying_down/laying_down425.png',
#  'laying_down/laying_down426.png',
#  'laying_down/laying_down427.png',
#  'laying_down/laying_down428.png',
#  'laying_down/laying_down429.png',
#  'laying_down/laying_down43.png',
#  'laying_down/laying_down430.png',
#  'laying_down/laying_down431.png',
#  'laying_down/laying_down432.png',
#  'laying_down/laying_down433.png',
#  'laying_down/laying_down434.png',
#  'laying_down/laying_down435.png',
#  'laying_down/laying_down436.png',
#  'laying_down/laying_down437.png',
#  'laying_down/laying_down438.png',
#  'laying_down/laying_down439.png',
#  'laying_down/laying_down44.png',
#  'laying_down/laying_down440.png',
#  'laying_down/laying_down441.png',
#  'laying_down/laying_down442.png',
#  'laying_down/laying_down443.png',
#  'laying_down/laying_down444.png',
#  'laying_down/laying_down445.png',
#  'laying_down/laying_down446.png',
#  'laying_down/laying_down447.png',
#  'laying_down/laying_down448.png',
#  'laying_down/laying_down449.png',
#  'laying_down/laying_down45.png',
#  'laying_down/laying_down450.png',
#  'laying_down/laying_down451.png',
#  'laying_down/laying_down452.png',
#  'laying_down/laying_down453.png',
#  'laying_down/laying_down454.png',
#  'laying_down/laying_down455.png',
#  'laying_down/laying_down456.png',
#  'laying_down/laying_down457.png',
#  'laying_down/laying_down458.png',
#  'laying_down/laying_down459.png',
#  'laying_down/laying_down46.png',
#  'laying_down/laying_down460.png',
#  'laying_down/laying_down461.png',
#  'laying_down/laying_down462.png',
#  'laying_down/laying_down463.png',
#  'laying_down/laying_down464.png',
#  'laying_down/laying_down465.png',
#  'laying_down/laying_down466.png',
#  'laying_down/laying_down467.png',
#  'laying_down/laying_down468.png',
#  'laying_down/laying_down469.png',
#  'laying_down/laying_down47.png',
#  'laying_down/laying_down470.png',
#  'laying_down/laying_down471.png',
#  'laying_down/laying_down472.png',
#  'laying_down/laying_down473.png',
#  'laying_down/laying_down474.png',
#  'laying_down/laying_down475.png',
#  'laying_down/laying_down476.png',
#  'laying_down/laying_down477.png',
#  'laying_down/laying_down478.png',
#  'laying_down/laying_down479.png',
#  'laying_down/laying_down48.png',
#  'laying_down/laying_down480.png',
#  'laying_down/laying_down481.png',
#  'laying_down/laying_down482.png',
#  'laying_down/laying_down49.png',
#  'laying_down/laying_down5.png',
#  'laying_down/laying_down50.png',
#  'laying_down/laying_down51.png',
#  'laying_down/laying_down52.png',
#  'laying_down/laying_down53.png',
#  'laying_down/laying_down54.png',
#  'laying_down/laying_down55.png',
#  'laying_down/laying_down56.png',
#  'laying_down/laying_down57.png',
#  'laying_down/laying_down58.png',
#  'laying_down/laying_down59.png',
#  'laying_down/laying_down6.png',
#  'laying_down/laying_down60.png',
#  'laying_down/laying_down61.png',
#  'laying_down/laying_down62.png',
#  'laying_down/laying_down63.png',
#  'laying_down/laying_down64.png',
#  'laying_down/laying_down65.png',
#  'laying_down/laying_down66.png',
#  'laying_down/laying_down67.png',
#  'laying_down/laying_down68.png',
#  'laying_down/laying_down69.png',
#  'laying_down/laying_down7.png',
#  'laying_down/laying_down70.png',
#  'laying_down/laying_down71.png',
#  'laying_down/laying_down72.png',
#  'laying_down/laying_down73.png',
#  'laying_down/laying_down74.png',
#  'laying_down/laying_down75.png',
#  'laying_down/laying_down76.png',
#  'laying_down/laying_down77.png',
#  'laying_down/laying_down78.png',
#  'laying_down/laying_down79.png',
#  'laying_down/laying_down8.png',
#  'laying_down/laying_down80.png',
#  'laying_down/laying_down81.png',
#  'laying_down/laying_down82.png',
#  'laying_down/laying_down83.png',
#  'laying_down/laying_down84.png',
#  'laying_down/laying_down85.png',
#  'laying_down/laying_down86.png',
#  'laying_down/laying_down87.png',
#  'laying_down/laying_down88.png',
#  'laying_down/laying_down89.png',
#  'laying_down/laying_down9.png',
#  'laying_down/laying_down90.png',
#  'laying_down/laying_down91.png',
#  'laying_down/laying_down92.png',
#  'laying_down/laying_down93.png',
#  'laying_down/laying_down94.png',
#  'laying_down/laying_down95.png',
#  'laying_down/laying_down96.png',
#  'laying_down/laying_down97.png',
#  'laying_down/laying_down98.png',
#  'laying_down/laying_down99.png',
#  'sitting/sitting1.png',
#  'sitting/sitting10.png',
#  'sitting/sitting100.png',
#  'sitting/sitting101.png',
#  'sitting/sitting102.png',
#  'sitting/sitting103.png',
#  'sitting/sitting104.png',
#  'sitting/sitting105.png',
#  'sitting/sitting106.png',
#  'sitting/sitting107.png',
#  'sitting/sitting108.png',
#  'sitting/sitting109.png',
#  'sitting/sitting11.png',
#  'sitting/sitting110.png',
#  'sitting/sitting111.png',
#  'sitting/sitting112.png',
#  'sitting/sitting113.png',
#  'sitting/sitting114.png',
#  'sitting/sitting115.png',
#  'sitting/sitting116.png',
#  'sitting/sitting117.png',
#  'sitting/sitting118.png',
#  'sitting/sitting119.png',
#  'sitting/sitting12.png',
#  'sitting/sitting120.png',
#  'sitting/sitting121.png',
#  'sitting/sitting122.png',
#  'sitting/sitting123.png',
#  'sitting/sitting124.png',
#  'sitting/sitting125.png',
#  'sitting/sitting126.png',
#  'sitting/sitting127.png',
#  'sitting/sitting128.png',
#  'sitting/sitting129.png',
#  'sitting/sitting13.png',
#  'sitting/sitting130.png',
#  'sitting/sitting131.png',
#  'sitting/sitting132.png',
#  'sitting/sitting133.png',
#  'sitting/sitting134.png',
#  'sitting/sitting135.png',
#  'sitting/sitting136.png',
#  'sitting/sitting137.png',
#  'sitting/sitting138.png',
#  'sitting/sitting139.png',
#  'sitting/sitting14.png',
#  'sitting/sitting140.png',
#  'sitting/sitting141.png',
#  'sitting/sitting142.png',
#  'sitting/sitting143.png',
#  'sitting/sitting144.png',
#  'sitting/sitting145.png',
#  'sitting/sitting146.png',
#  'sitting/sitting147.png',
#  'sitting/sitting148.png',
#  'sitting/sitting149.png',
#  'sitting/sitting15.png',
#  'sitting/sitting150.png',
#  'sitting/sitting151.png',
#  'sitting/sitting152.png',
#  'sitting/sitting153.png',
#  'sitting/sitting154.png',
#  'sitting/sitting155.png',
#  'sitting/sitting156.png',
#  'sitting/sitting157.png',
#  'sitting/sitting158.png',
#  'sitting/sitting159.png',
#  'sitting/sitting16.png',
#  'sitting/sitting160.png',
#  'sitting/sitting161.png',
#  'sitting/sitting162.png',
#  'sitting/sitting163.png',
#  'sitting/sitting164.png',
#  'sitting/sitting165.png',
#  'sitting/sitting166.png',
#  'sitting/sitting167.png',
#  'sitting/sitting168.png',
#  'sitting/sitting169.png',
#  'sitting/sitting17.png',
#  'sitting/sitting170.png',
#  'sitting/sitting171.png',
#  'sitting/sitting172.png',
#  'sitting/sitting173.png',
#  'sitting/sitting174.png',
#  'sitting/sitting175.png',
#  'sitting/sitting176.png',
#  'sitting/sitting177.png',
#  'sitting/sitting178.png',
#  'sitting/sitting179.png',
#  'sitting/sitting18.png',
#  'sitting/sitting180.png',
#  'sitting/sitting181.png',
#  'sitting/sitting182.png',
#  'sitting/sitting183.png',
#  'sitting/sitting184.png',
#  'sitting/sitting185.png',
#  'sitting/sitting186.png',
#  'sitting/sitting187.png',
#  'sitting/sitting188.png',
#  'sitting/sitting189.png',
#  'sitting/sitting19.png',
#  'sitting/sitting190.png',
#  'sitting/sitting191.png',
#  'sitting/sitting192.png',
#  'sitting/sitting193.png',
#  'sitting/sitting194.png',
#  'sitting/sitting195.png',
#  'sitting/sitting196.png',
#  'sitting/sitting197.png',
#  'sitting/sitting198.png',
#  'sitting/sitting199.png',
#  'sitting/sitting2.png',
#  'sitting/sitting20.png',
#  'sitting/sitting200.png',
#  'sitting/sitting201.png',
#  'sitting/sitting202.png',
#  'sitting/sitting203.png',
#  'sitting/sitting204.png',
#  'sitting/sitting205.png',
#  'sitting/sitting206.png',
#  'sitting/sitting207.png',
#  'sitting/sitting208.png',
#  'sitting/sitting209.png',
#  'sitting/sitting21.png',
#  'sitting/sitting210.png',
#  'sitting/sitting211.png',
#  'sitting/sitting212.png',
#  'sitting/sitting213.png',
#  'sitting/sitting214.png',
#  'sitting/sitting215.png',
#  'sitting/sitting216.png',
#  'sitting/sitting217.png',
#  'sitting/sitting218.png',
#  'sitting/sitting219.png',
#  'sitting/sitting22.png',
#  'sitting/sitting220.png',
#  'sitting/sitting221.png',
#  'sitting/sitting222.png',
#  'sitting/sitting223.png',
#  'sitting/sitting224.png',
#  'sitting/sitting225.png',
#  'sitting/sitting226.png',
#  'sitting/sitting227.png',
#  'sitting/sitting228.png',
#  'sitting/sitting229.png',
#  'sitting/sitting23.png',
#  'sitting/sitting230.png',
#  'sitting/sitting231.png',
#  'sitting/sitting232.png',
#  'sitting/sitting233.png',
#  'sitting/sitting234.png',
#  'sitting/sitting235.png',
#  'sitting/sitting236.png',
#  'sitting/sitting237.png',
#  'sitting/sitting238.png',
#  'sitting/sitting239.png',
#  'sitting/sitting24.png',
#  'sitting/sitting240.png',
#  'sitting/sitting241.png',
#  'sitting/sitting242.png',
#  'sitting/sitting243.png',
#  'sitting/sitting244.png',
#  'sitting/sitting245.png',
#  'sitting/sitting246.png',
#  'sitting/sitting247.png',
#  'sitting/sitting248.png',
#  'sitting/sitting249.png',
#  'sitting/sitting25.png',
#  'sitting/sitting250.png',
#  'sitting/sitting251.png',
#  'sitting/sitting252.png',
#  'sitting/sitting253.png',
#  'sitting/sitting254.png',
#  'sitting/sitting255.png',
#  'sitting/sitting256.png',
#  'sitting/sitting257.png',
#  'sitting/sitting258.png',
#  'sitting/sitting259.png',
#  'sitting/sitting26.png',
#  'sitting/sitting260.png',
#  'sitting/sitting261.png',
#  'sitting/sitting262.png',
#  'sitting/sitting263.png',
#  'sitting/sitting264.png',
#  'sitting/sitting265.png',
#  'sitting/sitting266.png',
#  'sitting/sitting267.png',
#  'sitting/sitting268.png',
#  'sitting/sitting269.png',
#  'sitting/sitting27.png',
#  'sitting/sitting270.png',
#  'sitting/sitting271.png',
#  'sitting/sitting272.png',
#  'sitting/sitting273.png',
#  'sitting/sitting274.png',
#  'sitting/sitting275.png',
#  'sitting/sitting276.png',
#  'sitting/sitting277.png',
#  'sitting/sitting278.png',
#  'sitting/sitting279.png',
#  'sitting/sitting28.png',
#  'sitting/sitting280.png',
#  'sitting/sitting281.png',
#  'sitting/sitting282.png',
#  'sitting/sitting283.png',
#  'sitting/sitting284.png',
#  'sitting/sitting285.png',
#  'sitting/sitting286.png',
#  'sitting/sitting287.png',
#  'sitting/sitting288.png',
#  'sitting/sitting289.png',
#  'sitting/sitting29.png',
#  'sitting/sitting290.png',
#  'sitting/sitting291.png',
#  'sitting/sitting292.png',
#  'sitting/sitting293.png',
#  'sitting/sitting294.png',
#  'sitting/sitting295.png',
#  'sitting/sitting296.png',
#  'sitting/sitting297.png',
#  'sitting/sitting298.png',
#  'sitting/sitting299.png',
#  'sitting/sitting3.png',
#  'sitting/sitting30.png',
#  'sitting/sitting300.png',
#  'sitting/sitting301.png',
#  'sitting/sitting302.png',
#  'sitting/sitting303.png',
#  'sitting/sitting304.png',
#  'sitting/sitting305.png',
#  'sitting/sitting306.png',
#  'sitting/sitting307.png',
#  'sitting/sitting308.png',
#  'sitting/sitting309.png',
#  'sitting/sitting31.png',
#  'sitting/sitting310.png',
#  'sitting/sitting311.png',
#  'sitting/sitting312.png',
#  'sitting/sitting313.png',
#  'sitting/sitting314.png',
#  'sitting/sitting315.png',
#  'sitting/sitting316.png',
#  'sitting/sitting317.png',
#  'sitting/sitting318.png',
#  'sitting/sitting319.png',
#  'sitting/sitting32.png',
#  'sitting/sitting320.png',
#  'sitting/sitting321.png',
#  'sitting/sitting322.png',
#  'sitting/sitting323.png',
#  'sitting/sitting324.png',
#  'sitting/sitting325.png',
#  'sitting/sitting326.png',
#  'sitting/sitting327.png',
#  'sitting/sitting328.png',
#  'sitting/sitting329.png',
#  'sitting/sitting33.png',
#  'sitting/sitting330.png',
#  'sitting/sitting331.png',
#  'sitting/sitting332.png',
#  'sitting/sitting333.png',
#  'sitting/sitting334.png',
#  'sitting/sitting335.png',
#  'sitting/sitting336.png',
#  'sitting/sitting337.png',
#  'sitting/sitting338.png',
#  'sitting/sitting339.png',
#  'sitting/sitting34.png',
#  'sitting/sitting340.png',
#  'sitting/sitting341.png',
#  'sitting/sitting342.png',
#  'sitting/sitting343.png',
#  'sitting/sitting344.png',
#  'sitting/sitting345.png',
#  'sitting/sitting346.png',
#  'sitting/sitting347.png',
#  'sitting/sitting348.png',
#  'sitting/sitting349.png',
#  'sitting/sitting35.png',
#  'sitting/sitting350.png',
#  'sitting/sitting351.png',
#  'sitting/sitting352.png',
#  'sitting/sitting353.png',
#  'sitting/sitting354.png',
#  'sitting/sitting355.png',
#  'sitting/sitting356.png',
#  'sitting/sitting357.png',
#  'sitting/sitting358.png',
#  'sitting/sitting359.png',
#  'sitting/sitting36.png',
#  'sitting/sitting360.png',
#  'sitting/sitting361.png',
#  'sitting/sitting362.png',
#  'sitting/sitting363.png',
#  'sitting/sitting364.png',
#  'sitting/sitting365.png',
#  'sitting/sitting366.png',
#  'sitting/sitting367.png',
#  'sitting/sitting368.png',
#  'sitting/sitting369.png',
#  'sitting/sitting37.png',
#  'sitting/sitting370.png',
#  'sitting/sitting371.png',
#  'sitting/sitting372.png',
#  'sitting/sitting373.png',
#  'sitting/sitting374.png',
#  'sitting/sitting375.png',
#  'sitting/sitting376.png',
#  'sitting/sitting377.png',
#  'sitting/sitting378.png',
#  'sitting/sitting379.png',
#  'sitting/sitting38.png',
#  'sitting/sitting380.png',
#  'sitting/sitting381.png',
#  'sitting/sitting382.png',
#  'sitting/sitting383.png',
#  'sitting/sitting384.png',
#  'sitting/sitting385.png',
#  'sitting/sitting386.png',
#  'sitting/sitting387.png',
#  'sitting/sitting388.png',
#  'sitting/sitting389.png',
#  'sitting/sitting39.png',
#  'sitting/sitting390.png',
#  'sitting/sitting391.png',
#  'sitting/sitting392.png',
#  'sitting/sitting393.png',
#  'sitting/sitting394.png',
#  'sitting/sitting395.png',
#  'sitting/sitting396.png',
#  'sitting/sitting397.png',
#  'sitting/sitting398.png',
#  'sitting/sitting399.png',
#  'sitting/sitting4.png',
#  'sitting/sitting40.png',
#  'sitting/sitting400.png',
#  'sitting/sitting401.png',
#  'sitting/sitting402.png',
#  'sitting/sitting403.png',
#  'sitting/sitting404.png',
#  'sitting/sitting405.png',
#  'sitting/sitting406.png',
#  'sitting/sitting407.png',
#  'sitting/sitting408.png',
#  'sitting/sitting409.png',
#  'sitting/sitting41.png',
#  'sitting/sitting410.png',
#  'sitting/sitting411.png',
#  'sitting/sitting412.png',
#  'sitting/sitting413.png',
#  'sitting/sitting414.png',
#  'sitting/sitting415.png',
#  'sitting/sitting416.png',
#  'sitting/sitting417.png',
#  'sitting/sitting418.png',
#  'sitting/sitting419.png',
#  'sitting/sitting42.png',
#  'sitting/sitting420.png',
#  'sitting/sitting421.png',
#  'sitting/sitting422.png',
#  'sitting/sitting423.png',
#  'sitting/sitting424.png',
#  'sitting/sitting425.png',
#  'sitting/sitting426.png',
#  'sitting/sitting427.png',
#  'sitting/sitting428.png',
#  'sitting/sitting429.png',
#  'sitting/sitting43.png',
#  'sitting/sitting430.png',
#  'sitting/sitting431.png',
#  'sitting/sitting432.png',
#  'sitting/sitting433.png',
#  'sitting/sitting434.png',
#  'sitting/sitting435.png',
#  'sitting/sitting436.png',
#  'sitting/sitting437.png',
#  'sitting/sitting438.png',
#  'sitting/sitting439.png',
#  'sitting/sitting44.png',
#  'sitting/sitting440.png',
#  'sitting/sitting441.png',
#  'sitting/sitting442.png',
#  'sitting/sitting443.png',
#  'sitting/sitting444.png',
#  'sitting/sitting445.png',
#  'sitting/sitting446.png',
#  'sitting/sitting447.png',
#  'sitting/sitting448.png',
#  'sitting/sitting449.png',
#  'sitting/sitting45.png',
#  'sitting/sitting450.png',
#  'sitting/sitting451.png',
#  'sitting/sitting452.png',
#  'sitting/sitting453.png',
#  'sitting/sitting454.png',
#  'sitting/sitting455.png',
#  'sitting/sitting456.png',
#  'sitting/sitting457.png',
#  'sitting/sitting46.png',
#  'sitting/sitting47.png',
#  'sitting/sitting48.png',
#  'sitting/sitting49.png',
#  'sitting/sitting5.png',
#  'sitting/sitting50.png',
#  'sitting/sitting51.png',
#  'sitting/sitting52.png',
#  'sitting/sitting53.png',
#  'sitting/sitting54.png',
#  'sitting/sitting55.png',
#  'sitting/sitting56.png',
#  'sitting/sitting57.png',
#  'sitting/sitting58.png',
#  'sitting/sitting59.png',
#  'sitting/sitting6.png',
#  'sitting/sitting60.png',
#  'sitting/sitting61.png',
#  'sitting/sitting62.png',
#  'sitting/sitting63.png',
#  'sitting/sitting64.png',
#  'sitting/sitting65.png',
#  'sitting/sitting66.png',
#  'sitting/sitting67.png',
#  'sitting/sitting68.png',
#  'sitting/sitting69.png',
#  'sitting/sitting7.png',
#  'sitting/sitting70.png',
#  'sitting/sitting71.png',
#  'sitting/sitting72.png',
#  'sitting/sitting73.png',
#  'sitting/sitting74.png',
#  'sitting/sitting75.png',
#  'sitting/sitting76.png',
#  'sitting/sitting77.png',
#  'sitting/sitting78.png',
#  'sitting/sitting79.png',
#  'sitting/sitting8.png',
#  'sitting/sitting80.png',
#  'sitting/sitting81.png',
#  'sitting/sitting82.png',
#  'sitting/sitting83.png',
#  'sitting/sitting84.png',
#  'sitting/sitting85.png',
#  'sitting/sitting86.png',
#  'sitting/sitting87.png',
#  'sitting/sitting88.png',
#  'sitting/sitting89.png',
#  'sitting/sitting9.png',
#  'sitting/sitting90.png',
#  'sitting/sitting91.png',
#  'sitting/sitting92.png',
#  'sitting/sitting93.png',
#  'sitting/sitting94.png',
#  'sitting/sitting95.png',
#  'sitting/sitting96.png',
#  'sitting/sitting97.png',
#  'sitting/sitting98.png',
#  'sitting/sitting99.png',
#  'standing/standing1.png',
#  'standing/standing10.png',
#  'standing/standing100.png',
#  'standing/standing101.png',
#  'standing/standing102.png',
#  'standing/standing103.png',
#  'standing/standing104.png',
#  'standing/standing105.png',
#  'standing/standing106.png',
#  'standing/standing107.png',
#  'standing/standing108.png',
#  'standing/standing109.png',
#  'standing/standing11.png',
#  'standing/standing110.png',
#  'standing/standing111.png',
#  'standing/standing112.png',
#  'standing/standing113.png',
#  'standing/standing114.png',
#  'standing/standing115.png',
#  'standing/standing116.png',
#  'standing/standing117.png',
#  'standing/standing118.png',
#  'standing/standing119.png',
#  'standing/standing12.png',
#  'standing/standing120.png',
#  'standing/standing121.png',
#  'standing/standing122.png',
#  'standing/standing123.png',
#  'standing/standing124.png',
#  'standing/standing125.png',
#  'standing/standing126.png',
#  'standing/standing127.png',
#  'standing/standing128.png',
#  'standing/standing129.png',
#  'standing/standing13.png',
#  'standing/standing130.png',
#  'standing/standing131.png',
#  'standing/standing132.png',
#  'standing/standing133.png',
#  'standing/standing134.png',
#  'standing/standing135.png',
#  'standing/standing136.png',
#  'standing/standing137.png',
#  'standing/standing138.png',
#  'standing/standing139.png',
#  'standing/standing14.png',
#  'standing/standing140.png',
#  'standing/standing141.png',
#  'standing/standing142.png',
#  'standing/standing143.png',
#  'standing/standing144.png',
#  'standing/standing145.png',
#  'standing/standing146.png',
#  'standing/standing147.png',
#  'standing/standing148.png',
#  'standing/standing149.png',
#  'standing/standing15.png',
#  'standing/standing150.png',
#  'standing/standing151.png',
#  'standing/standing152.png',
#  'standing/standing153.png',
#  ...]

# %%
y_test = [[1,0,0,0]]*len(color_map_spiral_test['laying_down'])+[[0,1,0,0]]*len(color_map_spiral_test['sitting'])+[[0,0,1,0]]*len(color_map_spiral_test['standing'])+[[0,0,0,1]]*len(color_map_spiral_test['walking'])

# %%
#print predict

def get_hot_value(my_list):
        max_val = max(my_list)
        return [int(item == max_val) for item in my_list]

hot_list = [get_hot_value(sublist) for sublist in predict]

t  = np.array(y_test)
p  = np.array(hot_list)
t = np.argmax(t, axis=1)
p = np.argmax(p, axis=1)

#print hot_list
print("Precision: ", precision_score(t, p, average=None))

from sklearn.metrics import accuracy_score
print accuracy_score(t, p)
# Out:
# ('Precision: ', array([0.52447552, 0.3       , 0.15517241, 0.17241379]))
# 0.3769230769230769

# %%
print len(predict)
print len(y_test)
# Out:
# 260
# 260

# %%
predict
# Out:
# array([[5.8263022e-01, 2.1142463e-04, 4.8962765e-04, 1.3432278e-07],
#        [3.8309439e-11, 7.4328858e-07, 7.5000443e-04, 9.8710746e-01],
#        [9.7089862e-12, 3.1170958e-07, 3.5227789e-04, 9.9163377e-01],
#        ...,
#        [4.5429063e-01, 2.1466911e-02, 9.0691159e-03, 1.7716477e-04],
#        [2.2617425e-03, 3.3544909e-02, 5.5353034e-01, 4.0908030e-04],
#        [5.2583563e-01, 1.3020625e-03, 1.6373862e-03, 2.6909156e-06]],
#       dtype=float32)

# %%
hot_list
